# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import onnx
import onnxruntime as ort
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import numpy as np
from torch.amp import GradScaler, autocast

# Define paths
base_dir = '/mnt/c/Users/rober/Desktop/GazeDetectionStudy'
dataset_dir = os.path.join(base_dir, 'natural_dataset')
real_eyes_dir = os.path.join(dataset_dir, 'real_eyes_for_testing')
model_save_dir = os.path.join(base_dir, 'models', 'natural_resnet')
os.makedirs(model_save_dir, exist_ok=True)

# Parameters
batch_size = 32  # Batch size for better GPU utilization
num_epochs = 100
learning_rate = 0.000001
num_classes = 3

# Data transforms (no augmentation for simplicity)
data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load training and testing datasets
train_dataset = datasets.ImageFolder(os.path.join(dataset_dir, 'train'), transform=data_transforms)
test_dataset = datasets.ImageFolder(os.path.join(dataset_dir, 'test'), transform=data_transforms)

# Optimized DataLoader with pin_memory and num_workers
num_workers = min(8, os.cpu_count())  # Use a high number of workers to speed up data loading
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=num_workers)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=num_workers)

# Load pre-trained ResNet-152 model and modify for 3 classes
model = models.resnet152(weights='ResNet152_Weights.IMAGENET1K_V1')
model.fc = nn.Linear(model.fc.in_features, num_classes)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Print CUDA device information
if torch.cuda.is_available():
    print(f"Using GPU: {torch.cuda.get_device_name(0)} with CUDA version {torch.version.cuda}")
else:
    print("CUDA is not available. Using CPU for training.")

# Enable CuDNN benchmarking for performance optimization
torch.backends.cudnn.benchmark = True

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)
scaler = GradScaler()  # For mixed-precision training

# Training loop
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    
    for batch_idx, (images, labels) in enumerate(train_loader, start=1):
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        # Mixed precision training
        with autocast('cuda'):
            outputs = model(images)
            loss = criterion(outputs, labels)
        
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        running_loss += loss.item()
        
        # Print epoch and batch number every 100 batches
        if batch_idx % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}/{len(train_loader)}]")

    train_losses.append(running_loss / len(train_loader))
    
    # Evaluation on the test set
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            
            # Mixed precision for evaluation
            with autocast('cuda'):
                outputs = model(images)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
    
    test_losses.append(test_loss / len(test_loader))
    test_accuracies.append(100 * correct / total)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, '
          f'Test Loss: {test_losses[-1]:.4f}, Test Accuracy: {test_accuracies[-1]:.2f}%')

# Save the model in .pth format
pth_model_path = os.path.join(model_save_dir, 'natural_resnet_gaze.pth')
torch.save(model.state_dict(), pth_model_path)
print(f'Model saved to {pth_model_path}')

# Export to ONNX
onnx_model_path = os.path.join(model_save_dir, 'natural_resnet_gaze.onnx')
dummy_input = torch.randn(1, 3, 224, 224, device=device)
torch.onnx.export(
    model, dummy_input, onnx_model_path, 
    input_names=['input'], output_names=['output'], 
    dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}},
    opset_version=14
)
print(f'Model exported to ONNX format at {onnx_model_path}')

# Verify ONNX model
onnx_model = onnx.load(onnx_model_path)
onnx.checker.check_model(onnx_model)

# Training Visualization with Seaborn
df = pd.DataFrame({
    'Epoch': range(1, num_epochs + 1),
    'Train Loss': train_losses,
    'Test Loss': test_losses,
    'Test Accuracy': test_accuracies
})

plt.figure(figsize=(10, 5))
sns.lineplot(x='Epoch', y='Train Loss', data=df, label='Train Loss')
sns.lineplot(x='Epoch', y='Test Loss', data=df, label='Test Loss')
sns.lineplot(x='Epoch', y='Test Accuracy', data=df, label='Test Accuracy')
plt.title('Training and Testing Metrics')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Evaluate on real images
class_names = ['Up', 'Down', 'Center']
model.eval()

for cls in class_names:
    image_path = os.path.join(real_eyes_dir, f'{cls}.jpg')
    if os.path.exists(image_path):
        image = Image.open(image_path)
        image = data_transforms(image).unsqueeze(0).to(device)
        
        with torch.no_grad():
            output = model(image)
            _, predicted = torch.max(output, 1)
            predicted_class = class_names[predicted.item()]
        
        print(f'Real image "{cls}.jpg" predicted as "{predicted_class}".')

print("Evaluation on real images complete.")
# Out:
# Using GPU: NVIDIA GeForce RTX 4070 with CUDA version 12.4
# Epoch [1/100], Train Loss: 1.0965, Test Loss: 1.0925, Test Accuracy: 41.78%
# Epoch [2/100], Train Loss: 1.0790, Test Loss: 1.0875, Test Accuracy: 35.27%
# Epoch [3/100], Train Loss: 1.0580, Test Loss: 1.0871, Test Accuracy: 40.75%
# Epoch [4/100], Train Loss: 1.0305, Test Loss: 1.0797, Test Accuracy: 39.73%
# Epoch [5/100], Train Loss: 1.0171, Test Loss: 1.0734, Test Accuracy: 42.12%
# Epoch [6/100], Train Loss: 0.9953, Test Loss: 1.0655, Test Accuracy: 44.18%
# Epoch [7/100], Train Loss: 0.9814, Test Loss: 1.0584, Test Accuracy: 47.60%
# Epoch [8/100], Train Loss: 0.9588, Test Loss: 1.0506, Test Accuracy: 46.23%
# Epoch [9/100], Train Loss: 0.9301, Test Loss: 1.0429, Test Accuracy: 49.66%
# Epoch [10/100], Train Loss: 0.9180, Test Loss: 1.0358, Test Accuracy: 49.32%
# Epoch [11/100], Train Loss: 0.8977, Test Loss: 1.0323, Test Accuracy: 49.32%
# Epoch [12/100], Train Loss: 0.8799, Test Loss: 1.0216, Test Accuracy: 52.05%
# Epoch [13/100], Train Loss: 0.8720, Test Loss: 1.0157, Test Accuracy: 52.40%
# Epoch [14/100], Train Loss: 0.8407, Test Loss: 1.0085, Test Accuracy: 51.37%
# Epoch [15/100], Train Loss: 0.8318, Test Loss: 1.0049, Test Accuracy: 52.05%
# Epoch [16/100], Train Loss: 0.8097, Test Loss: 0.9978, Test Accuracy: 53.08%
# Epoch [17/100], Train Loss: 0.7827, Test Loss: 0.9889, Test Accuracy: 53.77%
# Epoch [18/100], Train Loss: 0.7672, Test Loss: 0.9788, Test Accuracy: 54.79%
# Epoch [19/100], Train Loss: 0.7500, Test Loss: 0.9774, Test Accuracy: 54.45%
# Epoch [20/100], Train Loss: 0.7267, Test Loss: 0.9717, Test Accuracy: 54.45%
# Epoch [21/100], Train Loss: 0.7117, Test Loss: 0.9591, Test Accuracy: 56.51%
# Epoch [22/100], Train Loss: 0.6815, Test Loss: 0.9577, Test Accuracy: 54.79%
# Epoch [23/100], Train Loss: 0.6658, Test Loss: 0.9487, Test Accuracy: 56.51%
# Epoch [24/100], Train Loss: 0.6402, Test Loss: 0.9385, Test Accuracy: 59.25%
# Epoch [25/100], Train Loss: 0.6160, Test Loss: 0.9351, Test Accuracy: 58.22%
# Epoch [26/100], Train Loss: 0.6045, Test Loss: 0.9268, Test Accuracy: 58.22%
# Epoch [27/100], Train Loss: 0.5768, Test Loss: 0.9257, Test Accuracy: 60.62%
# Epoch [28/100], Train Loss: 0.5542, Test Loss: 0.9120, Test Accuracy: 60.27%
# Epoch [29/100], Train Loss: 0.5406, Test Loss: 0.9077, Test Accuracy: 58.90%
# Epoch [30/100], Train Loss: 0.5250, Test Loss: 0.9008, Test Accuracy: 58.90%
# Epoch [31/100], Train Loss: 0.5042, Test Loss: 0.8934, Test Accuracy: 59.59%
# Epoch [32/100], Train Loss: 0.4795, Test Loss: 0.8845, Test Accuracy: 60.27%
# Epoch [33/100], Train Loss: 0.4619, Test Loss: 0.8870, Test Accuracy: 59.25%
# Epoch [34/100], Train Loss: 0.4555, Test Loss: 0.8738, Test Accuracy: 60.96%
# Epoch [35/100], Train Loss: 0.4157, Test Loss: 0.8704, Test Accuracy: 60.27%
# Epoch [36/100], Train Loss: 0.4225, Test Loss: 0.8638, Test Accuracy: 60.27%
# Epoch [37/100], Train Loss: 0.3724, Test Loss: 0.8590, Test Accuracy: 60.62%
# Epoch [38/100], Train Loss: 0.3795, Test Loss: 0.8558, Test Accuracy: 59.93%
# Epoch [39/100], Train Loss: 0.3467, Test Loss: 0.8473, Test Accuracy: 63.01%
# Epoch [40/100], Train Loss: 0.3333, Test Loss: 0.8418, Test Accuracy: 61.99%
# Epoch [41/100], Train Loss: 0.3102, Test Loss: 0.8476, Test Accuracy: 60.62%
# Epoch [42/100], Train Loss: 0.2853, Test Loss: 0.8347, Test Accuracy: 62.33%
# Epoch [43/100], Train Loss: 0.3047, Test Loss: 0.8323, Test Accuracy: 61.30%
# Epoch [44/100], Train Loss: 0.2790, Test Loss: 0.8313, Test Accuracy: 63.01%
# Epoch [45/100], Train Loss: 0.2582, Test Loss: 0.8304, Test Accuracy: 61.64%
# Epoch [46/100], Train Loss: 0.2401, Test Loss: 0.8222, Test Accuracy: 63.01%
# Epoch [47/100], Train Loss: 0.2367, Test Loss: 0.8153, Test Accuracy: 62.33%
# Epoch [48/100], Train Loss: 0.2364, Test Loss: 0.8140, Test Accuracy: 63.01%
# Epoch [49/100], Train Loss: 0.2140, Test Loss: 0.8125, Test Accuracy: 63.36%
# Epoch [50/100], Train Loss: 0.1875, Test Loss: 0.8112, Test Accuracy: 62.33%
# Epoch [51/100], Train Loss: 0.1979, Test Loss: 0.8119, Test Accuracy: 63.01%
# Epoch [52/100], Train Loss: 0.1893, Test Loss: 0.8152, Test Accuracy: 62.33%
# Epoch [53/100], Train Loss: 0.1737, Test Loss: 0.8011, Test Accuracy: 62.33%
# Epoch [54/100], Train Loss: 0.1523, Test Loss: 0.7969, Test Accuracy: 62.33%
# Epoch [55/100], Train Loss: 0.1501, Test Loss: 0.8046, Test Accuracy: 62.33%
# Epoch [56/100], Train Loss: 0.1711, Test Loss: 0.8028, Test Accuracy: 64.04%
# Epoch [57/100], Train Loss: 0.1303, Test Loss: 0.8013, Test Accuracy: 61.99%
# Epoch [58/100], Train Loss: 0.1754, Test Loss: 0.7940, Test Accuracy: 63.36%
# Epoch [59/100], Train Loss: 0.1836, Test Loss: 0.8113, Test Accuracy: 62.67%
# Epoch [60/100], Train Loss: 0.1425, Test Loss: 0.7978, Test Accuracy: 62.33%
# Epoch [61/100], Train Loss: 0.1209, Test Loss: 0.7990, Test Accuracy: 62.33%
# Epoch [62/100], Train Loss: 0.1215, Test Loss: 0.7992, Test Accuracy: 60.62%
# Epoch [63/100], Train Loss: 0.1173, Test Loss: 0.7930, Test Accuracy: 60.96%
# Epoch [64/100], Train Loss: 0.0959, Test Loss: 0.7928, Test Accuracy: 63.01%
# Epoch [65/100], Train Loss: 0.0971, Test Loss: 0.7919, Test Accuracy: 63.36%
# Epoch [66/100], Train Loss: 0.0919, Test Loss: 0.7917, Test Accuracy: 63.70%
# Epoch [67/100], Train Loss: 0.0938, Test Loss: 0.7896, Test Accuracy: 62.67%
# Epoch [68/100], Train Loss: 0.0852, Test Loss: 0.7872, Test Accuracy: 61.30%
# Epoch [69/100], Train Loss: 0.1056, Test Loss: 0.7967, Test Accuracy: 63.01%
# Epoch [70/100], Train Loss: 0.0994, Test Loss: 0.7854, Test Accuracy: 64.38%
# Epoch [71/100], Train Loss: 0.0831, Test Loss: 0.7996, Test Accuracy: 60.96%
# Epoch [72/100], Train Loss: 0.0735, Test Loss: 0.8054, Test Accuracy: 60.62%
# Epoch [73/100], Train Loss: 0.0701, Test Loss: 0.8051, Test Accuracy: 60.96%
# Epoch [74/100], Train Loss: 0.0645, Test Loss: 0.8107, Test Accuracy: 60.27%
# Epoch [75/100], Train Loss: 0.0965, Test Loss: 0.8085, Test Accuracy: 60.62%
# Epoch [76/100], Train Loss: 0.0633, Test Loss: 0.8062, Test Accuracy: 63.36%
# Epoch [77/100], Train Loss: 0.0610, Test Loss: 0.7993, Test Accuracy: 60.62%
# Epoch [78/100], Train Loss: 0.0911, Test Loss: 0.7915, Test Accuracy: 61.99%
# Epoch [79/100], Train Loss: 0.0545, Test Loss: 0.7959, Test Accuracy: 61.64%
# Epoch [80/100], Train Loss: 0.0460, Test Loss: 0.7941, Test Accuracy: 61.99%
# Epoch [81/100], Train Loss: 0.0577, Test Loss: 0.8179, Test Accuracy: 60.62%
# Epoch [82/100], Train Loss: 0.0551, Test Loss: 0.7900, Test Accuracy: 61.30%
# Epoch [83/100], Train Loss: 0.0563, Test Loss: 0.8032, Test Accuracy: 60.62%
# Epoch [84/100], Train Loss: 0.0630, Test Loss: 0.8080, Test Accuracy: 61.30%
# Epoch [85/100], Train Loss: 0.0998, Test Loss: 0.7995, Test Accuracy: 63.01%
# Epoch [86/100], Train Loss: 0.0451, Test Loss: 0.7806, Test Accuracy: 60.96%
# Epoch [87/100], Train Loss: 0.0423, Test Loss: 0.7929, Test Accuracy: 62.67%
# Epoch [88/100], Train Loss: 0.0515, Test Loss: 0.8074, Test Accuracy: 59.25%
# Epoch [89/100], Train Loss: 0.0396, Test Loss: 0.7938, Test Accuracy: 63.70%
# Epoch [90/100], Train Loss: 0.0667, Test Loss: 0.8032, Test Accuracy: 64.04%
# Epoch [91/100], Train Loss: 0.0389, Test Loss: 0.8108, Test Accuracy: 63.70%
# Epoch [92/100], Train Loss: 0.0445, Test Loss: 0.8083, Test Accuracy: 61.99%
# Epoch [93/100], Train Loss: 0.0568, Test Loss: 0.7957, Test Accuracy: 64.73%
# Epoch [94/100], Train Loss: 0.0352, Test Loss: 0.8088, Test Accuracy: 61.64%
# Epoch [95/100], Train Loss: 0.0410, Test Loss: 0.8066, Test Accuracy: 61.30%
# Epoch [96/100], Train Loss: 0.0413, Test Loss: 0.8039, Test Accuracy: 62.33%
# Epoch [97/100], Train Loss: 0.0351, Test Loss: 0.7914, Test Accuracy: 64.04%
# Epoch [98/100], Train Loss: 0.0424, Test Loss: 0.8027, Test Accuracy: 61.30%
# Epoch [99/100], Train Loss: 0.0359, Test Loss: 0.8064, Test Accuracy: 63.70%
# Epoch [100/100], Train Loss: 0.0375, Test Loss: 0.8087, Test Accuracy: 61.99%
# Model saved to /mnt/c/Users/rober/Desktop/GazeDetectionStudy/models/natural_resnet/natural_resnet_gaze.pth
# Model exported to ONNX format at /mnt/c/Users/rober/Desktop/GazeDetectionStudy/models/natural_resnet/natural_resnet_gaze.onnx
# Real image "Up.jpg" predicted as "Center".
# Real image "Down.jpg" predicted as "Center".
# Real image "Center.jpg" predicted as "Up".
# Evaluation on real images complete.
